# %% [markdown]
# ## String Slicing – 50 Questions
#
# Use this string for Questions 1–10:
#
# ```python
# s = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789abcdefghijklmnopqrstuvwxyz"
# ```
#
# 1. Find the output:
#
# ```python
# s[5:50:3][::-2]
# ```
#
# 2. Find the output:
#
# ```python
# s[-5:10:-4]
# ```
#
# 3. Find the output:
#
# ```python
# s[::-1][7:40:5]
# ```
#
# 4. Find the output:
#
# ```python
# s[2:-3:4][1:-2:2]
# ```
#
# 5. Find the output:
#
# ```python
# s[-2::-3][4:15:3]
# ```
#
# 6. Find the output:
#
# ```python
# s[::2][::-3][2:10]
# ```
#
# 7. Find the output:
#
# ```python
# s[-10:5:-2][::-1]
# ```
#
# 8. Find the output:
#
# ```python
# s[3:55:5][-2::-2]
# ```
#
# 9. Find the output:
#
# ```python
# s[::-4][1:10][::-2]
# ```
#
# 10. Without using `reverse()`, create a slice that extracts every 5th character from the end toward the beginning, but skips the last two characters.
#
# ---
#
# Use:
#
# ```python
# s = "DataScienceMachineLearningArtificialIntelligenceDeepLearning"
# ```
#
# 11. Find the output:
#
# ```python
# s[4:45:3][::-1]
# ```
#
# 12. Find the output:
#
# ```python
# s[-1:-40:-3][2::2]
# ```
#
# 13. Find the output:
#
# ```python
# s[5:-5:2][::-3]
# ```
#
# 14. Find the output:
#
# ```python
# s[::-1][10:35:4][1:-1]
# ```
#
# 15. Find the output:
#
# ```python
# s[::3][-2::-2]
# ```
#
# 16. Extract `"MachineLearning"` using slicing only.
#
# 17. Extract `"ArtificialIntelligence"` in reverse using slicing only.
#
# 18. Extract alternate characters only from the substring `"MachineLearning"`.
#
# 19. Take the last 30 characters, reverse them, then return every 4th character.
#
# 20. Write one expression using chained slicing that:
#
# * removes the first 5 characters,
# * removes the last 7 characters,
# * takes every second character,
# * reverses the result,
# * then keeps every third character.
#
# ---
#
# Use:
#
# ```python
# s = "a1B2c3D4e5F6g7H8i9J0kLmNoPqRsTuVwXyZ"
# ```
#
# 21. Find:
#
# ```python
# s[1::3][::-2]
# ```
#
# 22. Find:
#
# ```python
# s[-3:2:-4]
# ```
#
# 23. Find:
#
# ```python
# s[::-2][3:14:2]
# ```
#
# 24. Find:
#
# ```python
# s[4:-4:3][::-1][2::3]
# ```
#
# 25. Find:
#
# ```python
# s[-1::-5][-2::-1]
# ```
#
# 26. Extract only characters located at original indices:
#
# ```text
# 2, 6, 10, 14, 18, 22...
# ```
#
# using one slice.
#
# 27. Extract the same sequence as Question 26, but in reverse order.
#
# 28. Find:
#
# ```python
# s[3:30:4][::-1][1:-1:2]
# ```
#
# 29. Find:
#
# ```python
# s[-5::-3][2:12:3]
# ```
#
# 30. Predict whether the result is empty or non-empty:
#
# ```python
# s[5:20:-2]
# ```
#
# Explain why.
#
# ---
#
# Now use a much more complex string:
#
# ```python
# s = "PYTHON_2026|DATA-SCIENCE@AI#ML$DEEP_LEARNING%GENAI&LLM*RAG"
# ```
#
# 31. Find the result:
#
# ```python
# s[3:-4:4][::-2]
# ```
#
# 32. Find:
#
# ```python
# s[-2:5:-5]
# ```
#
# 33. Find:
#
# ```python
# s[::-1][6:35:3]
# ```
#
# 34. Find:
#
# ```python
# s[5:40:2][2:-3:3]
# ```
#
# 35. Find:
#
# ```python
# s[-10:-50:-4][::-1]
# ```
#
# 36. Extract `"DATA-SCIENCE"` using slicing only.
#
# 37. Extract `"DEEP_LEARNING"` backwards using slicing only.
#
# 38. Extract the final `"RAG"` in reverse using negative indexing only.
#
# 39. Find:
#
# ```python
# s[::2][3:-5][::-4]
# ```
#
# 40. Find:
#
# ```python
# s[::-3][::-2][1:8]
# ```
#
# ---
#
# ## Very Hard: Dynamic Slicing
#
# Use:
#
# ```python
# s = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"
# ```
#
# 41. Find the output:
#
# ```python
# s[len(s)//4 : 3*len(s)//4 : 3]
# ```
#
# 42. Find:
#
# ```python
# s[-len(s)//2 : -3 : 4]
# ```
#
# 43. Find:
#
# ```python
# s[len(s)-5 : len(s)//3 : -3]
# ```
#
# 44. Find:
#
# ```python
# s[::-1][len(s)//5 : len(s)//2 : 2]
# ```
#
# 45. Find:
#
# ```python
# s[2:-2:3][len(s)//10::-2]
# ```
#
# ---
#
# ## Expert Level: Multi-stage Slicing
#
# 46. Find the exact output:
#
# ```python
# s = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
#
# result = s[2:24:2][::-1][1:8:2]
# ```
#
# 47. Find:
#
# ```python
# s = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
#
# result = s[::-1][3:30:3][::-2]
# ```
#
# 48. Find:
#
# ```python
# s = "abcdefghijklmnopqrstuvwxyz"
#
# result = s[1:-1:2][::-1][2:9:3]
# ```
#
# 49. Find:
#
# ```python
# s = "PythonStringSlicingIsVeryInteresting"
#
# result = s[-3:2:-3][1::2][::-1]
# ```
#
# 50. This is the hardest one. Find the final output step by step:
#
# ```python
# s = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789abcdefghijklmnopqrstuvwxyz"
#
# result = s[3:-4:2][::-1][2:-3:3][::-2][1:7]
# ```
